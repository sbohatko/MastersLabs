# %%
import pandas as pd

# %% [markdown]
# Обрати датасет, вивести датасет

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sbohatko/MastersLabs/main/farmersTweets.csv', on_bad_lines='skip')

# %%
df.head()
# Out:
#           username        displayname        userId  \
# 0   ShashiRajbhar6     Shashi Rajbhar  1.020000e+18
# 1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1.330000e+18
# 2    SukhdevSingh_      Sukhdev Singh  1.310000e+18
# 3  Davidmu66668113     tera jija 🤨🚩🇺🇸  1.360000e+18
# 4   Abhimanyu_1987     Abhimanyu 🌏 🇮🇳  2.918611e+09
#
#                                       rawDescription descriptionUrls  \
# 0  Satya presan 🤔ho Sakta but prajit💪 nhi\r\njhut...              []
# 1        ਜਿਓਣਾ ਕੀ ਸਰੀਰਾਂ ਦਾ ਜੇਕਰ ਹੋਣ ਜ਼ਮੀਰਾਂ ਮਰੀਆਂ 🌼              []
# 2  Just a part of my society . Social and Politic...              []
# 3                                     dream boy 🌪🌍🔥💯              []
# 4                                          Seeker...              []
#
#    verified                    created  followersCount  friendsCount  \
# 0     False  2018-07-08T14:44:03+00:00            1788          1576
# 1     False  2020-11-29T06:40:06+00:00              51            68
# ...

# %% [markdown]
# З'ясувати чи є дані, що відсутні (NaN), виконати заміну відсутніх даних, наприклад на 0.0

# %%
df_filled = df.fillna(0.0)

# %%
df_filled.head()
# Out:
#           username        displayname        userId  \
# 0   ShashiRajbhar6     Shashi Rajbhar  1.020000e+18
# 1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1.330000e+18
# 2    SukhdevSingh_      Sukhdev Singh  1.310000e+18
# 3  Davidmu66668113     tera jija 🤨🚩🇺🇸  1.360000e+18
# 4   Abhimanyu_1987     Abhimanyu 🌏 🇮🇳  2.918611e+09
#
#                                       rawDescription descriptionUrls  \
# 0  Satya presan 🤔ho Sakta but prajit💪 nhi\r\njhut...              []
# 1        ਜਿਓਣਾ ਕੀ ਸਰੀਰਾਂ ਦਾ ਜੇਕਰ ਹੋਣ ਜ਼ਮੀਰਾਂ ਮਰੀਆਂ 🌼              []
# 2  Just a part of my society . Social and Politic...              []
# 3                                     dream boy 🌪🌍🔥💯              []
# 4                                          Seeker...              []
#
#    verified                    created  followersCount  friendsCount  \
# 0     False  2018-07-08T14:44:03+00:00            1788          1576
# 1     False  2020-11-29T06:40:06+00:00              51            68
# ...

# %% [markdown]
# Продемонструвати видалення всіх об'єктів з NaN

# %%
df_cleaned = df.dropna()

# %%
df_cleaned.head()
# Out:
#            username                        displayname        userId  \
# 18   HarkeshHaryana                   Harkesh Dhankhar  9.670000e+17
# 21  SatishBalsamand   Satish Balsamand ਸਤੀਸ਼ ਬਲਸਾਮੰਦ 🚜  2.712238e+09
# 36     bhupenderc19  Bhupender Chaudhary ਭੁਪਿੰਦਰ ਚੌਧਰੀ  5.041070e+08
# 45     samitakaur74                        Samita Kaur  2.366478e+09
# 46   suneetmahandru                    Suneet Mahandru  3.105449e+07
#
#                                        rawDescription descriptionUrls  \
# 18  State Coordinator,\r\n@Haryana_YC Social Media...              []
# 21  #Son_of_Farmer || Believe in true ideology of ...              []
# 36  Member-Bharatiya Kisan Union\r\n,All India Jat...              []
# 45                        strive to achieve happiness              []
# 46  ☬ sicker than your average🎥📸@suneetmahandru #F...              []
#
#     verified                    created  followersCount  friendsCount  \
# ...

# %% [markdown]
# Виконати сумування декількох стовбців для додавання підсумкового стовбця.

# %%
df['total_count'] = df['followersCount'] + df['friendsCount']

# %%
df.head()
# Out:
#           username        displayname        userId  \
# 0   ShashiRajbhar6     Shashi Rajbhar  1.020000e+18
# 1  kaursuk06272818  KAUR SUKH🌾ਕੌਰ ਸੁਖ  1.330000e+18
# 2    SukhdevSingh_      Sukhdev Singh  1.310000e+18
# 3  Davidmu66668113     tera jija 🤨🚩🇺🇸  1.360000e+18
# 4   Abhimanyu_1987     Abhimanyu 🌏 🇮🇳  2.918611e+09
#
#                                       rawDescription descriptionUrls  \
# 0  Satya presan 🤔ho Sakta but prajit💪 nhi\r\njhut...              []
# 1        ਜਿਓਣਾ ਕੀ ਸਰੀਰਾਂ ਦਾ ਜੇਕਰ ਹੋਣ ਜ਼ਮੀਰਾਂ ਮਰੀਆਂ 🌼              []
# 2  Just a part of my society . Social and Politic...              []
# 3                                     dream boy 🌪🌍🔥💯              []
# 4                                          Seeker...              []
#
#    verified                    created  followersCount  friendsCount  \
# 0     False  2018-07-08T14:44:03+00:00            1788          1576
# 1     False  2020-11-29T06:40:06+00:00              51            68
# ...

# %% [markdown]
# Зробити проміжні висновки по декількох категоріям.

# %%
print(df['location'].value_counts())

# %%
print(df['verified'].value_counts())
# Out:
# False    698
# True      13
# Name: verified, dtype: int64
